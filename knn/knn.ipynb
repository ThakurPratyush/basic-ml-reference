# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_classification

X,y = make_classification(
    n_samples = 1000,
    n_features = 3,
    n_redundant = 1,
    n_classes = 2,
    random_state = 99
)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.33, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier(n_neighbors = 5, algorithm = 'auto')
# p= 1 manhatan p =2 eucledian (default) , algorithm = 'kdtree', ball, auto (decides best automatically)
# wights uniform (all points given equal weight  , distance : inverse of distacnce, udf
#

# %%
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
print(confusion_matrix(y_pred, y_test))
print(accuracy_score(y_pred, y_test))
print(classification_report(y_pred, y_test))
# Out:
# [[166  13]
#  [  7 144]]
# 0.9393939393939394
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       179
#            1       0.92      0.95      0.94       151
#
#     accuracy                           0.94       330
#    macro avg       0.94      0.94      0.94       330
# weighted avg       0.94      0.94      0.94       330

# %%
model = KNeighborsClassifier(algorithm='auto')

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = { 'n_neighbors':[3,5,2,1,10,13],
                'weights' : ['uniform','distance'],
                'p' :  [1,2]
             }

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold()

# %%
grid = GridSearchCV(estimator = model,param_grid = param_grid, refit = True, cv = cv)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 2, 1, 10, 13], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']})

# %%
grid.best_score_
# Out:
# 0.9805970149253731

# %%
grid.best_params_
# Out:
# {'n_neighbors': 2, 'p': 1, 'weights': 'distance'}
